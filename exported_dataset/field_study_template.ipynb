# %% [markdown]
# # Template notebook

# %% [markdown]
# Create a copy of this template for each data field you study. Don't cram all your work into one notebook!

# %%
import pandas as pd
import numpy as np

from utils import *

# %%
df = load_csv_export_dataset("export_dataframe_stage2.csv")
# Out:
# /Users/robclewley/.pyenv/versions/3.7.5/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (12,18,19,21,22,29,30,31,33,34,54,61,62,63,64,70,71,72,75,76,77,84,85,86) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  group_rid  \
# 0           0             0        840
# 1           1             1        840
# 2           2             2        297
# 3           3             3        297
# 4           4             4        297
#
#                                            GroupName  site_rid  \
# 0                                    Rails to Trails        18
# 1                                    Rails to Trails        18
# 2  Apalachee Water Watchers, Walton Clean & Beaut...        44
# 3  Apalachee Water Watchers, Walton Clean & Beaut...        44
# 4  Apalachee Water Watchers, Walton Clean & Beaut...        44
#
#                     SiteName       SiteLocation  event_rid  \
# 0  West Fork of Little River  34.4103  -83.8462         92
# 1  West Fork of Little River  34.4103  -83.8462         93
# 2            Apalachee River  33.8406  -83.5584         94
# 3            Apalachee River  33.8406  -83.5584         95
# ...
