# %%
import pandas as pd
import numpy as np
import csv
from collections import defaultdict, Counter

# %%
df = pd.read_csv("export_dataframe_stage1.csv")

# %% [markdown]
# ## Explore apparent multiplicity of some columns

# %% [markdown]
# e.g. `Salinity1` and `Salinity2`. Without knowing the original context for these, are the values the same when both are not null?
#
# Spoiler alert: the scraped version of the data indicates that these are measurements made at two (still unclear) separate times of the "sample", so that an average is possibly most appropriate to take. (But how long between the measurements? Consistently same time between measurements?).

# %%
multi_names = [
    ("ph1", "ph2"),
    ("Salinity1", "Salinity2"),
    ("SecchiDisk1", "SecchiDisk2"),
    ("DissolvedOxygen1", "DissolvedOxygen2"),
    ]

# %%
def two_column_mutex_null_test(df: pd.DataFrame, col1: str, col2: str, null_value='NULL') -> dict:
    """Assumes column values are True or False (bool python datatype).
    """
    return {"both_null": len(df[np.logical_and(df[col1] == null_value, df[col2] == null_value)]),
             "both_not_null": len(df[np.logical_and(~(df[col1] == null_value), ~(df[col2] == null_value))]),
            "first_null_only": len(df[np.logical_and(df[col1] == null_value, ~(df[col2] == null_value))]),
            "second_null_only": len(df[np.logical_and(~(df[col1] == null_value), df[col2] == null_value)]),
             "total": len(df)}

# %%
def both_not_null_filter(df: pd.DataFrame, col1: str, col2: str, null_value='NULL') -> pd.DataFrame:
    return df[np.logical_and(~(df[col1] == null_value), ~(df[col2] == null_value))]

# %%
for n1, n2 in multi_names:
    print("******")
    print(n1, n2)
    print(two_column_mutex_null_test(d2, n1, n2))
    test_df = both_not_null_filter(d2, n1, n2)
    print(len(test_df[test_df[n1] == test_df[n2]])/len(test_df), len(test_df))
    print(test_df[[n1, n2]].head())
    anoms = test_df[test_df[n1] != test_df[n2]]
    print(anoms[[n1, n2]].head())
# Out:
# ******
# ph1 ph2
# {'both_null': 25162, 'both_not_null': 38788, 'first_null_only': 0, 'second_null_only': 1, 'total': 63951}
# 0.9296174074456017 38788
#    ph1  ph2
# 0    7    7
# 1  6.5  6.5
# 2  5.5  5.5
# 3    7    7
# 4  6.6  6.6
#         ph1   ph2
# 21069     7  6.75
# 21071     7  6.75
# 21072  6.75     7
# 21074     6  6.25
# 21076   6.8   7.5
# ******
# Salinity1 Salinity2
# {'both_null': 57758, 'both_not_null': 6192, 'first_null_only': 0, 'second_null_only': 1, 'total': 63951}
# 0.8959948320413437 6192
#      Salinity1 Salinity2
# 3987        27        27
# 3988        24        24
# 3990        30        30
# 3991        28        28
# 3992        34        34
#       Salinity1 Salinity2
# 21154         7         8
# 21185        29        30
# 21186        32        33
# 21188        30        31
# 21317        24        22
# ******
# SecchiDisk1 SecchiDisk2
# {'both_null': 57488, 'both_not_null': 6463, 'first_null_only': 0, 'second_null_only': 0, 'total': 63951}
# 0.8106142658208263 6463
#      SecchiDisk1 SecchiDisk2
# 3987          99          99
# 3988          36          36
# 3989          62          62
# 3990         3.5         3.5
# 3991         110         110
#       SecchiDisk1 SecchiDisk2
# 20343         105         103
# 21111         136         134
# 21154         110         120
# 21185          85          88
# 21187          70          72
# ******
# DissolvedOxygen1 DissolvedOxygen2
# {'both_null': 24942, 'both_not_null': 39007, 'first_null_only': 0, 'second_null_only': 2, 'total': 63951}
# 0.6352449560335325 39007
#   DissolvedOxygen1 DissolvedOxygen2
# 0              7.6              7.6
# 1              7.2              7.2
# 2              8.1              8.1
# 3              7.7              7.7
# 4              7.4              7.4
#       DissolvedOxygen1 DissolvedOxygen2
# 20002              9.9               10
# 20003               11             11.2
# 20068              7.2              6.9
# 20069             10.2             10.3
# 20293              8.4                9

# %% [markdown]
# ## Spot check values on a single day

# %%
day_lo = pd.to_datetime("2005-07-30 00:00:00")
day_hi = pd.to_datetime("2005-07-31 00:00:00")

def day_test(dt_val):
    return dt_val >= day_lo and dt_val < day_hi

# %%
dict(data[data["event_date"].apply(day_test)].iloc[0])
# Out:
# {'group_rid': 747,
#  'GroupName': 'Sandy Creek Nature Center Volunteers',
#  'site_rid': 580,
#  'SiteName': 'Sandy  Creek',
#  'SiteLocation': '33.9806  -83.3802',
#  'event_rid': 3348,
#  'event_date': Timestamp('2005-07-30 10:15:00'),
#  'volunteer_time': '180',
#  'data_entry': '9416',
#  'participants': '5',
#  'rain_24_hours': 'Intermittent Rain',
#  'weather': 'Intermittent',
#  'rain_hours': 'NULL',
#  'rain_inches': 'NULL',
#  'distance': 'NULL',
#  'air_temperature': '24.5',
#  'stream': 'NULL',
#  'method': 'NULL',
#  'wqi': 'NULL',
#  'habitat': 'NULL',
#  'Comments': 'NULL',
#  'createdby': 'EPDMIG',
#  'createddate': '3/10/17 11:48 PM',
#  'chem_detail_rid': 12655,
#  'air_temp': '24.5',
#  'water_temp': '25',
#  'calibrate': '0',
#  'calibrate_comment': 'NULL',
#  'chemical_comment': 'NULL',
#  'ChemWarnings': 'NULL',
#  'do_saturation': '65.79',
#  'reagent': 'NULL',
#  'reagent_other': 'NULL',
#  'ph1': '6.5',
#  'ph2': '6.5',
#  'DissolvedOxygen1': '5.5',
#  'DissolvedOxygen2': '5.5',
#  'Conductivity': 'NULL',
#  'Salinity1': 'NULL',
#  'Salinity2': 'NULL',
#  'SecchiDisk1': 'NULL',
#  'SecchiDisk2': 'NULL',
#  'ChlorophyllA': 'NULL',
#  'Alkalinity': '39',
#  'AmmoniaN': 'NULL',
#  'NitrateN': '0',
#  'Orthophosphate': '0',
#  'SamplingDepth': 'NULL',
#  'SettleableSolids': 'NULL',
#  'Turbidity': 'NULL',
#  'Chloride': 'NULL',
#  'Hardness': 'NULL',
#  'Other1': 'NULL',
#  'Other2': 'NULL',
#  'Other3': 'NULL',
#  'Other4': 'NULL',
#  'Other5': 'NULL',
#  'Other6': 'NULL',
#  'Other7': 'NULL',
#  'Other1_Comm': 'NULL',
#  'Other2_Comm': 'NULL',
#  'Other3_Comm': 'NULL',
#  'Other4_Comm': 'NULL',
#  'Other5_Comm': 'NULL',
#  'Other6_Comm': 'NULL',
#  'Other7_Comm': 'NULL',
#  'bact_detail_rid': -1,
#  'plate_blank': 'NULL',
#  'plate_one': 'NULL',
#  'plate_two': 'NULL',
#  'plate_three': 'NULL',
#  'plate_four': 'NULL',
#  'plate_five': 'NULL',
#  'colony_avg': 'NULL',
#  'hold_start_datetime': 'NULL',
#  'hold_end_datetime': 'NULL',
#  'min_temp': 'NULL',
#  'max_temp': 'NULL',
#  'three_M_plate': 'NULL',
#  'ecoli_idexx': 'NULL',
#  'fecal_coliform': 'NULL',
#  'ecoli_other': 'NULL',
#  'ecoli_other_unit': 'NULL',
#  'comments': 'NULL',
#  'warnings': 'NULL'}

# %%
test_day = data[data["event_date"] == "2005-07-30 12:00:00"]

# %%
test_day
# Out:
#       group_rid GroupName  site_rid              SiteName       SiteLocation  \
# 2995        433      UOWN       477  Bear Creek Tributary  33.9679  -83.4973
# 3021        433      UOWN       662          McNutt Creek  33.9265  -83.4276
# 3022        433      UOWN       663    Orange Trail Creek  33.9029  -83.3796
# 3023        433      UOWN       664   Middle Oconee River  33.9576  -83.4384
# 3024        433      UOWN       476       Hunnicutt Creek   33.9581  -83.437
# 3025        433      UOWN       666        Brooklyn Creek  33.9476  -83.3941
# 3026        433      UOWN       667           Sandy Creek  33.9806  -83.3819
# 3027        433      UOWN       668          Barber Creek  33.9691  -83.3883
# 3028        433      UOWN       669           Trail Creek  33.9544  -83.3659
# 3029        433      UOWN       670          Barber Creek  33.9669  -83.3906
# 3030        433      UOWN       671    North Oconee River   33.957  -83.3664
# 3031        433      UOWN       672         Pulaski Creek  33.9694  -83.3787
# 3032        433      UOWN       673    North Bypass Creek  33.9774  -83.3851
# 3033        433      UOWN       674    North Bypass Creek  33.9756  -83.3933
# 3034        433      UOWN       675            Carr Creek  33.9476  -83.3516
# 3035        433      UOWN       676    North Oconee River  33.9318  -83.3598
# 3036        433      UOWN       677          shoals creek  33.9694  -83.3041
# 3037        433      UOWN       678           Cedar Creek  33.9219  -83.3276
#
#       event_rid          event_date volunteer_time data_entry participants  \
# 2995       3466 2005-07-30 12:00:00             60       6150            1
# 3021       3500 2005-07-30 12:00:00             60       6150            1
# 3022       3501 2005-07-30 12:00:00             60       6150            1
# 3023       3502 2005-07-30 12:00:00             60       6150            1
# 3024       3503 2005-07-30 12:00:00             60       6150            1
# 3025       3504 2005-07-30 12:00:00             60       6150            1
# 3026       3505 2005-07-30 12:00:00             60       6150            1
# 3027       3506 2005-07-30 12:00:00             60       6150            1
# 3028       3507 2005-07-30 12:00:00             60       6150            1
# 3029       3508 2005-07-30 12:00:00             60       6150            1
# 3030       3509 2005-07-30 12:00:00             60       6150            1
# 3031       3510 2005-07-30 12:00:00             60       6150            1
# 3032       3511 2005-07-30 12:00:00             60       6150            1
# 3033       3512 2005-07-30 12:00:00             60       6150            1
# 3034       3513 2005-07-30 12:00:00             60       6150            1
# 3035       3514 2005-07-30 12:00:00             60       6150            1
# 3036       3515 2005-07-30 12:00:00             60       6150            1
# 3037       3516 2005-07-30 12:00:00             60       6150            1
#
#       ... hold_end_datetime min_temp max_temp three_M_plate ecoli_idexx  \
# 2995  ...              NULL     NULL     NULL             1        NULL
# 3021  ...              NULL     NULL     NULL             1        NULL
# 3022  ...              NULL     NULL     NULL             1        NULL
# 3023  ...              NULL     NULL     NULL          NULL        NULL
# 3024  ...              NULL     NULL     NULL             1        NULL
# 3025  ...              NULL     NULL     NULL             1        NULL
# 3026  ...              NULL     NULL     NULL             1        NULL
# 3027  ...              NULL     NULL     NULL             1        NULL
# 3028  ...              NULL     NULL     NULL             1        NULL
# 3029  ...              NULL     NULL     NULL             1        NULL
# 3030  ...              NULL     NULL     NULL          NULL        NULL
# 3031  ...              NULL     NULL     NULL          NULL        NULL
# 3032  ...              NULL     NULL     NULL             1        NULL
# 3033  ...              NULL     NULL     NULL             1        NULL
# 3034  ...              NULL     NULL     NULL          NULL        NULL
# 3035  ...              NULL     NULL     NULL          NULL        NULL
# 3036  ...              NULL     NULL     NULL             1        NULL
# 3037  ...              NULL     NULL     NULL             1        NULL
#
#      fecal_coliform ecoli_other ecoli_other_unit comments warnings
# 2995            250        NULL             NULL     NULL     NULL
# 3021           1500        NULL             NULL     NULL     NULL
# 3022           -100        NULL             NULL     NULL     NULL
# 3023           NULL        NULL             NULL     NULL     NULL
# 3024           -100        NULL             NULL     NULL     NULL
# 3025           -100        NULL             NULL     NULL     NULL
# 3026            570        NULL             NULL     NULL     NULL
# 3027           2100        NULL             NULL     NULL     NULL
# 3028             10        NULL             NULL     NULL     NULL
# 3029             10        NULL             NULL     NULL     NULL
# 3030           NULL        NULL             NULL     NULL     NULL
# 3031           NULL        NULL             NULL     NULL     NULL
# 3032            600        NULL             NULL     NULL     NULL
# 3033           1800        NULL             NULL     NULL     NULL
# 3034           NULL        NULL             NULL     NULL     NULL
# 3035           NULL        NULL             NULL     NULL     NULL
# 3036           -100        NULL             NULL     NULL     NULL
# 3037            150        NULL             NULL     NULL     NULL
#
# [18 rows x 85 columns]
